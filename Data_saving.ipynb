# %% [markdown]
# ### Data modify

# %%
import os
import shutil

'''
This file extract labeled and original photos in cityscapes dataset. Rename the 
files and put them in the same directory.

The function will save the photos end with 'labelIds.png' in 'gtFine' folder to 
destination path. Also save photos end with 'leftImg8bit.png' in 'leftImg8bit'
folder to the same path. The file name is modified based on the dataset, index
and type of the photos.

des_path: the destination path of the saved data. The directory will be
created automaticly if not exist. Three sub folders: train, test, valid
will be created in this directory.

Please place the folder 'gtFine' and 'leftImg8bit' in the same
folder, and pass the path of 'gtFine' to the function as the argument. 

File transfer walk through the files in 'gtFine' and will 
extract corresponding files which has the same name in 'leftImg8bit'
folder. Save them to the destination path.

05/19/2018

'''


des_path = '/datasets/home/14/214/c6du/data/Cityscape_modified/'
if not os.path.isdir(des_path):
        os.mkdir(des_path)

obj_folder = [des_path + 'train',
              des_path + 'valid',
              des_path + 'test']

for dir_i in obj_folder:
    if not os.path.isdir(dir_i):
        os.mkdir(dir_i)

def file_transfer(dirname):

    result = []#所有的文件
    cnt_train = 0
    cnt_valid = 0
    cnt_test = 0
    
    for maindir, subdir, file_name_list in os.walk(dirname):
        
        path_sep_lst = maindir.split('/')
        
        if path_sep_lst[-2] == 'test':
            path_sep_lst[-3] = 'leftImg8bit'
          
            for filename in file_name_list:
                file_sep_lst = filename.split('_')
                
                if file_sep_lst[-1] == 'labelIds.png':
                    file_sep_lst.pop(-1)
                    #print(file_sep_lst)
                    file_sep_lst[-1] = 'leftImg8bit.png'
                    
                    apath_lbl = os.path.join(maindir, filename)
                    
                    maindir_ori = ''
                    filename_ori = ''
                    for word in path_sep_lst:
                        maindir_ori = maindir_ori + word + '/'
                    
                    for word in file_sep_lst:
                        filename_ori = filename_ori + word +'_'
                    filename_ori = filename_ori[:-1]
                    
                    apath_ori = os.path.join(maindir_ori, filename_ori)
  
                    dst_file_lbl = 'test_' + '{0:05d}'.format(cnt_test) + '_lbl.png'
                    shutil.copy2(apath_lbl, obj_folder[2] + '/' + dst_file_lbl)
                    print('transfer name from ' + filename + ' to ' + dst_file_lbl)
                    
                    dst_file_ori = 'test_' + '{0:05d}'.format(cnt_test) + '_ori.png'
                    shutil.copy2(apath_ori, obj_folder[2] + '/' + dst_file_ori)
                    print('transfer name from ' + filename_ori + ' to ' + dst_file_ori)
                    
                    cnt_test += 1
                    
                    
                    
        if path_sep_lst[-2] == 'train':
            path_sep_lst[-3] = 'leftImg8bit'
          
            for filename in file_name_list:
                file_sep_lst = filename.split('_')
                
                if file_sep_lst[-1] == 'labelIds.png':
                    file_sep_lst.pop(-1)
                    #print(file_sep_lst)
                    file_sep_lst[-1] = 'leftImg8bit.png'
                    
                    apath_lbl = os.path.join(maindir, filename)
                    
                    maindir_ori = ''
                    filename_ori = ''
                    for word in path_sep_lst:
                        maindir_ori = maindir_ori + word + '/'
                    
                    for word in file_sep_lst:
                        filename_ori = filename_ori + word +'_'
                    filename_ori = filename_ori[:-1]
                    
                    apath_ori = os.path.join(maindir_ori, filename_ori)
  
                    dst_file_lbl = 'train_' + '{0:05d}'.format(cnt_train) + '_lbl.png'
                    shutil.copy2(apath_lbl, obj_folder[0] + '/' + dst_file_lbl)
                    print('transfer name from ' + filename + ' to ' + dst_file_lbl)
                    
                    dst_file_ori = 'train_' + '{0:05d}'.format(cnt_train) + '_ori.png'
                    shutil.copy2(apath_ori, obj_folder[0] + '/' + dst_file_ori)
                    print('transfer name from ' + filename_ori + ' to ' + dst_file_ori)
                    
                    cnt_train += 1
                    
                   
        if path_sep_lst[-2] == 'val':
            path_sep_lst[-3] = 'leftImg8bit'
          
            for filename in file_name_list:
                file_sep_lst = filename.split('_')
                
                if file_sep_lst[-1] == 'labelIds.png':
                    file_sep_lst.pop(-1)
                    #print(file_sep_lst)
                    file_sep_lst[-1] = 'leftImg8bit.png'
                    
                    apath_lbl = os.path.join(maindir, filename)
                    
                    maindir_ori = ''
                    filename_ori = ''
                    for word in path_sep_lst:
                        maindir_ori = maindir_ori + word + '/'
                    
                    for word in file_sep_lst:
                        filename_ori = filename_ori + word +'_'
                    filename_ori = filename_ori[:-1]
                    
                    apath_ori = os.path.join(maindir_ori, filename_ori)
  
                    dst_file_lbl = 'valid_' + '{0:05d}'.format(cnt_valid) + '_lbl.png'
                    shutil.copy2(apath_lbl, obj_folder[1] + '/' + dst_file_lbl)
                    print('transfer name from ' + filename + ' to ' + dst_file_lbl)
                    
                    dst_file_ori = 'valid_' + '{0:05d}'.format(cnt_valid) + '_ori.png'
                    shutil.copy2(apath_ori, obj_folder[1] + '/' + dst_file_ori)
                    print('transfer name from ' + filename_ori + ' to ' + dst_file_ori)
                    
                    cnt_valid += 1
                
file_transfer('/datasets/home/14/214/c6du/data/' + 'Cityscapes/gtFine')
# Out:
# transfer name from darmstadt_000023_000019_gtFine_labelIds.png to train_00000_lbl.png
# transfer name from darmstadt_000023_000019_leftImg8bit.png to train_00000_ori.png
# transfer name from darmstadt_000057_000019_gtFine_labelIds.png to train_00001_lbl.png
# transfer name from darmstadt_000057_000019_leftImg8bit.png to train_00001_ori.png
# transfer name from darmstadt_000003_000019_gtFine_labelIds.png to train_00002_lbl.png
# transfer name from darmstadt_000003_000019_leftImg8bit.png to train_00002_ori.png
# transfer name from darmstadt_000077_000019_gtFine_labelIds.png to train_00003_lbl.png
# transfer name from darmstadt_000077_000019_leftImg8bit.png to train_00003_ori.png
# transfer name from darmstadt_000017_000019_gtFine_labelIds.png to train_00004_lbl.png
# transfer name from darmstadt_000017_000019_leftImg8bit.png to train_00004_ori.png
# transfer name from darmstadt_000063_000019_gtFine_labelIds.png to train_00005_lbl.png
# transfer name from darmstadt_000063_000019_leftImg8bit.png to train_00005_ori.png
# transfer name from darmstadt_000037_000019_gtFine_labelIds.png to train_00006_lbl.png
# transfer name from darmstadt_000037_000019_leftImg8bit.png to train_00006_ori.png
# transfer name from darmstadt_000043_000019_gtFine_labelIds.png to train_00007_lbl.png
# transfer name from darmstadt_000043_000019_leftImg8bit.png to train_00007_ori.png
# transfer name from darmstadt_000083_000019_gtFine_labelIds.png to train_00008_lbl.png
# transfer name from darmstadt_000083_000019_leftImg8bit.png to train_00008_ori.png
# transfer name from darmstadt_000082_000019_gtFine_labelIds.png to train_00009_lbl.png
# transfer name from darmstadt_000082_000019_leftImg8bit.png to train_00009_ori.png
# transfer name from darmstadt_000022_000019_gtFine_labelIds.png to train_00010_lbl.png
# transfer name from darmstadt_000022_000019_leftImg8bit.png to train_00010_ori.png
# transfer name from darmstadt_000056_000019_gtFine_labelIds.png to train_00011_lbl.png
# transfer name from darmstadt_000056_000019_leftImg8bit.png to train_00011_ori.png
# transfer name from darmstadt_000002_000019_gtFine_labelIds.png to train_00012_lbl.png
# transfer name from darmstadt_000002_000019_leftImg8bit.png to train_00012_ori.png
# transfer name from darmstadt_000076_000019_gtFine_labelIds.png to train_00013_lbl.png
# transfer name from darmstadt_000076_000019_leftImg8bit.png to train_00013_ori.png
# transfer name from darmstadt_000016_000019_gtFine_labelIds.png to train_00014_lbl.png
# transfer name from darmstadt_000016_000019_leftImg8bit.png to train_00014_ori.png
# transfer name from darmstadt_000062_000019_gtFine_labelIds.png to train_00015_lbl.png
# transfer name from darmstadt_000062_000019_leftImg8bit.png to train_00015_ori.png
# transfer name from darmstadt_000036_000019_gtFine_labelIds.png to train_00016_lbl.png
# transfer name from darmstadt_000036_000019_leftImg8bit.png to train_00016_ori.png
# transfer name from darmstadt_000042_000019_gtFine_labelIds.png to train_00017_lbl.png
# transfer name from darmstadt_000042_000019_leftImg8bit.png to train_00017_ori.png
# transfer name from darmstadt_000048_000019_gtFine_labelIds.png to train_00018_lbl.png
# transfer name from darmstadt_000048_000019_leftImg8bit.png to train_00018_ori.png
# transfer name from darmstadt_000080_000019_gtFine_labelIds.png to train_00019_lbl.png
# transfer name from darmstadt_000080_000019_leftImg8bit.png to train_00019_ori.png
# transfer name from darmstadt_000068_000019_gtFine_labelIds.png to train_00020_lbl.png
# transfer name from darmstadt_000068_000019_leftImg8bit.png to train_00020_ori.png
# transfer name from darmstadt_000008_000019_gtFine_labelIds.png to train_00021_lbl.png
# transfer name from darmstadt_000008_000019_leftImg8bit.png to train_00021_ori.png
# transfer name from darmstadt_000028_000019_gtFine_labelIds.png to train_00022_lbl.png
# transfer name from darmstadt_000028_000019_leftImg8bit.png to train_00022_ori.png
# transfer name from darmstadt_000054_000019_gtFine_labelIds.png to train_00023_lbl.png
# transfer name from darmstadt_000054_000019_leftImg8bit.png to train_00023_ori.png
# transfer name from darmstadt_000020_000019_gtFine_labelIds.png to train_00024_lbl.png
# transfer name from darmstadt_000020_000019_leftImg8bit.png to train_00024_ori.png
# transfer name from darmstadt_000074_000019_gtFine_labelIds.png to train_00025_lbl.png
# transfer name from darmstadt_000074_000019_leftImg8bit.png to train_00025_ori.png
# transfer name from darmstadt_000000_000019_gtFine_labelIds.png to train_00026_lbl.png
# transfer name from darmstadt_000000_000019_leftImg8bit.png to train_00026_ori.png
# transfer name from darmstadt_000060_000019_gtFine_labelIds.png to train_00027_lbl.png
# transfer name from darmstadt_000060_000019_leftImg8bit.png to train_00027_ori.png
# transfer name from darmstadt_000014_000019_gtFine_labelIds.png to train_00028_lbl.png
# transfer name from darmstadt_000014_000019_leftImg8bit.png to train_00028_ori.png
# transfer name from darmstadt_000040_000019_gtFine_labelIds.png to train_00029_lbl.png
# transfer name from darmstadt_000040_000019_leftImg8bit.png to train_00029_ori.png
# transfer name from darmstadt_000034_000019_gtFine_labelIds.png to train_00030_lbl.png
# transfer name from darmstadt_000034_000019_leftImg8bit.png to train_00030_ori.png
# transfer name from darmstadt_000055_000019_gtFine_labelIds.png to train_00031_lbl.png
# transfer name from darmstadt_000055_000019_leftImg8bit.png to train_00031_ori.png
# transfer name from darmstadt_000021_000019_gtFine_labelIds.png to train_00032_lbl.png
# transfer name from darmstadt_000021_000019_leftImg8bit.png to train_00032_ori.png
# transfer name from darmstadt_000075_000019_gtFine_labelIds.png to train_00033_lbl.png
# transfer name from darmstadt_000075_000019_leftImg8bit.png to train_00033_ori.png
# transfer name from darmstadt_000001_000019_gtFine_labelIds.png to train_00034_lbl.png
# transfer name from darmstadt_000001_000019_leftImg8bit.png to train_00034_ori.png
# transfer name from darmstadt_000061_000019_gtFine_labelIds.png to train_00035_lbl.png
# transfer name from darmstadt_000061_000019_leftImg8bit.png to train_00035_ori.png
# transfer name from darmstadt_000015_000019_gtFine_labelIds.png to train_00036_lbl.png
# transfer name from darmstadt_000015_000019_leftImg8bit.png to train_00036_ori.png
# transfer name from darmstadt_000041_000019_gtFine_labelIds.png to train_00037_lbl.png
# transfer name from darmstadt_000041_000019_leftImg8bit.png to train_00037_ori.png
# transfer name from darmstadt_000035_000019_gtFine_labelIds.png to train_00038_lbl.png
# transfer name from darmstadt_000035_000019_leftImg8bit.png to train_00038_ori.png
# transfer name from darmstadt_000049_000019_gtFine_labelIds.png to train_00039_lbl.png
# transfer name from darmstadt_000049_000019_leftImg8bit.png to train_00039_ori.png
# transfer name from darmstadt_000081_000019_gtFine_labelIds.png to train_00040_lbl.png
# transfer name from darmstadt_000081_000019_leftImg8bit.png to train_00040_ori.png
# transfer name from darmstadt_000069_000019_gtFine_labelIds.png to train_00041_lbl.png
# transfer name from darmstadt_000069_000019_leftImg8bit.png to train_00041_ori.png
# transfer name from darmstadt_000009_000019_gtFine_labelIds.png to train_00042_lbl.png
# transfer name from darmstadt_000009_000019_leftImg8bit.png to train_00042_ori.png
# transfer name from darmstadt_000029_000019_gtFine_labelIds.png to train_00043_lbl.png
# transfer name from darmstadt_000029_000019_leftImg8bit.png to train_00043_ori.png
# transfer name from darmstadt_000018_000019_gtFine_labelIds.png to train_00044_lbl.png
# transfer name from darmstadt_000018_000019_leftImg8bit.png to train_00044_ori.png
# transfer name from darmstadt_000084_000019_gtFine_labelIds.png to train_00045_lbl.png
# transfer name from darmstadt_000084_000019_leftImg8bit.png to train_00045_ori.png
# transfer name from darmstadt_000038_000019_gtFine_labelIds.png to train_00046_lbl.png
# transfer name from darmstadt_000038_000019_leftImg8bit.png to train_00046_ori.png
# transfer name from darmstadt_000058_000019_gtFine_labelIds.png to train_00047_lbl.png
# transfer name from darmstadt_000058_000019_leftImg8bit.png to train_00047_ori.png
# transfer name from darmstadt_000078_000019_gtFine_labelIds.png to train_00048_lbl.png
# transfer name from darmstadt_000078_000019_leftImg8bit.png to train_00048_ori.png
# transfer name from darmstadt_000004_000019_gtFine_labelIds.png to train_00049_lbl.png
# transfer name from darmstadt_000004_000019_leftImg8bit.png to train_00049_ori.png
# transfer name from darmstadt_000070_000019_gtFine_labelIds.png to train_00050_lbl.png
# transfer name from darmstadt_000070_000019_leftImg8bit.png to train_00050_ori.png
# transfer name from darmstadt_000024_000019_gtFine_labelIds.png to train_00051_lbl.png
# transfer name from darmstadt_000024_000019_leftImg8bit.png to train_00051_ori.png
# transfer name from darmstadt_000050_000019_gtFine_labelIds.png to train_00052_lbl.png
# transfer name from darmstadt_000050_000019_leftImg8bit.png to train_00052_ori.png
# transfer name from darmstadt_000030_000019_gtFine_labelIds.png to train_00053_lbl.png
# transfer name from darmstadt_000030_000019_leftImg8bit.png to train_00053_ori.png
# transfer name from darmstadt_000044_000019_gtFine_labelIds.png to train_00054_lbl.png
# transfer name from darmstadt_000044_000019_leftImg8bit.png to train_00054_ori.png
# transfer name from darmstadt_000010_000019_gtFine_labelIds.png to train_00055_lbl.png
# transfer name from darmstadt_000010_000019_leftImg8bit.png to train_00055_ori.png
# transfer name from darmstadt_000064_000019_gtFine_labelIds.png to train_00056_lbl.png
# transfer name from darmstadt_000064_000019_leftImg8bit.png to train_00056_ori.png
# transfer name from darmstadt_000005_000019_gtFine_labelIds.png to train_00057_lbl.png
# transfer name from darmstadt_000005_000019_leftImg8bit.png to train_00057_ori.png
# transfer name from darmstadt_000071_000019_gtFine_labelIds.png to train_00058_lbl.png
# transfer name from darmstadt_000071_000019_leftImg8bit.png to train_00058_ori.png
# transfer name from darmstadt_000025_000019_gtFine_labelIds.png to train_00059_lbl.png
# transfer name from darmstadt_000025_000019_leftImg8bit.png to train_00059_ori.png
# transfer name from darmstadt_000051_000019_gtFine_labelIds.png to train_00060_lbl.png
# transfer name from darmstadt_000051_000019_leftImg8bit.png to train_00060_ori.png
# transfer name from darmstadt_000031_000019_gtFine_labelIds.png to train_00061_lbl.png
# transfer name from darmstadt_000031_000019_leftImg8bit.png to train_00061_ori.png
# transfer name from darmstadt_000045_000019_gtFine_labelIds.png to train_00062_lbl.png
# transfer name from darmstadt_000045_000019_leftImg8bit.png to train_00062_ori.png
# transfer name from darmstadt_000011_000019_gtFine_labelIds.png to train_00063_lbl.png
# transfer name from darmstadt_000011_000019_leftImg8bit.png to train_00063_ori.png
# transfer name from darmstadt_000065_000019_gtFine_labelIds.png to train_00064_lbl.png
# transfer name from darmstadt_000065_000019_leftImg8bit.png to train_00064_ori.png
# transfer name from darmstadt_000019_000019_gtFine_labelIds.png to train_00065_lbl.png
# transfer name from darmstadt_000019_000019_leftImg8bit.png to train_00065_ori.png
# transfer name from darmstadt_000039_000019_gtFine_labelIds.png to train_00066_lbl.png
# transfer name from darmstadt_000039_000019_leftImg8bit.png to train_00066_ori.png
# transfer name from darmstadt_000059_000019_gtFine_labelIds.png to train_00067_lbl.png
# transfer name from darmstadt_000059_000019_leftImg8bit.png to train_00067_ori.png
# transfer name from darmstadt_000079_000019_gtFine_labelIds.png to train_00068_lbl.png
# transfer name from darmstadt_000079_000019_leftImg8bit.png to train_00068_ori.png
# transfer name from darmstadt_000073_000019_gtFine_labelIds.png to train_00069_lbl.png
# transfer name from darmstadt_000073_000019_leftImg8bit.png to train_00069_ori.png
# transfer name from darmstadt_000007_000019_gtFine_labelIds.png to train_00070_lbl.png
# transfer name from darmstadt_000007_000019_leftImg8bit.png to train_00070_ori.png
# transfer name from darmstadt_000053_000019_gtFine_labelIds.png to train_00071_lbl.png
# transfer name from darmstadt_000053_000019_leftImg8bit.png to train_00071_ori.png
# transfer name from darmstadt_000027_000019_gtFine_labelIds.png to train_00072_lbl.png
# transfer name from darmstadt_000027_000019_leftImg8bit.png to train_00072_ori.png
# transfer name from darmstadt_000047_000019_gtFine_labelIds.png to train_00073_lbl.png
# transfer name from darmstadt_000047_000019_leftImg8bit.png to train_00073_ori.png
# transfer name from darmstadt_000033_000019_gtFine_labelIds.png to train_00074_lbl.png
# transfer name from darmstadt_000033_000019_leftImg8bit.png to train_00074_ori.png
# transfer name from darmstadt_000067_000019_gtFine_labelIds.png to train_00075_lbl.png
# transfer name from darmstadt_000067_000019_leftImg8bit.png to train_00075_ori.png
# transfer name from darmstadt_000013_000019_gtFine_labelIds.png to train_00076_lbl.png
# transfer name from darmstadt_000013_000019_leftImg8bit.png to train_00076_ori.png
# transfer name from darmstadt_000072_000019_gtFine_labelIds.png to train_00077_lbl.png
# transfer name from darmstadt_000072_000019_leftImg8bit.png to train_00077_ori.png
# transfer name from darmstadt_000006_000019_gtFine_labelIds.png to train_00078_lbl.png
# transfer name from darmstadt_000006_000019_leftImg8bit.png to train_00078_ori.png
# transfer name from darmstadt_000052_000019_gtFine_labelIds.png to train_00079_lbl.png
# transfer name from darmstadt_000052_000019_leftImg8bit.png to train_00079_ori.png
# transfer name from darmstadt_000026_000019_gtFine_labelIds.png to train_00080_lbl.png
# transfer name from darmstadt_000026_000019_leftImg8bit.png to train_00080_ori.png
# transfer name from darmstadt_000046_000019_gtFine_labelIds.png to train_00081_lbl.png
# transfer name from darmstadt_000046_000019_leftImg8bit.png to train_00081_ori.png
# transfer name from darmstadt_000032_000019_gtFine_labelIds.png to train_00082_lbl.png
# transfer name from darmstadt_000032_000019_leftImg8bit.png to train_00082_ori.png
# transfer name from darmstadt_000066_000019_gtFine_labelIds.png to train_00083_lbl.png
# transfer name from darmstadt_000066_000019_leftImg8bit.png to train_00083_ori.png
# transfer name from darmstadt_000012_000019_gtFine_labelIds.png to train_00084_lbl.png
# transfer name from darmstadt_000012_000019_leftImg8bit.png to train_00084_ori.png
# transfer name from bochum_000000_031922_gtFine_labelIds.png to train_00085_lbl.png
# transfer name from bochum_000000_031922_leftImg8bit.png to train_00085_ori.png
# transfer name from bochum_000000_007651_gtFine_labelIds.png to train_00086_lbl.png
# transfer name from bochum_000000_007651_leftImg8bit.png to train_00086_ori.png
# transfer name from bochum_000000_021393_gtFine_labelIds.png to train_00087_lbl.png
# transfer name from bochum_000000_021393_leftImg8bit.png to train_00087_ori.png
# transfer name from bochum_000000_009951_gtFine_labelIds.png to train_00088_lbl.png
# transfer name from bochum_000000_009951_leftImg8bit.png to train_00088_ori.png
# transfer name from bochum_000000_004229_gtFine_labelIds.png to train_00089_lbl.png
# transfer name from bochum_000000_004229_leftImg8bit.png to train_00089_ori.png
# transfer name from bochum_000000_020673_gtFine_labelIds.png to train_00090_lbl.png
# transfer name from bochum_000000_020673_leftImg8bit.png to train_00090_ori.png
# transfer name from bochum_000000_010700_gtFine_labelIds.png to train_00091_lbl.png
# transfer name from bochum_000000_010700_leftImg8bit.png to train_00091_ori.png
# transfer name from bochum_000000_027699_gtFine_labelIds.png to train_00092_lbl.png
# transfer name from bochum_000000_027699_leftImg8bit.png to train_00092_ori.png
# transfer name from bochum_000000_019188_gtFine_labelIds.png to train_00093_lbl.png
# transfer name from bochum_000000_019188_leftImg8bit.png to train_00093_ori.png
# transfer name from bochum_000000_027951_gtFine_labelIds.png to train_00094_lbl.png
# transfer name from bochum_000000_027951_leftImg8bit.png to train_00094_ori.png
# transfer name from bochum_000000_023174_gtFine_labelIds.png to train_00095_lbl.png
# transfer name from bochum_000000_023174_leftImg8bit.png to train_00095_ori.png
# transfer name from bochum_000000_020899_gtFine_labelIds.png to train_00096_lbl.png
# transfer name from bochum_000000_020899_leftImg8bit.png to train_00096_ori.png
# transfer name from bochum_000000_008162_gtFine_labelIds.png to train_00097_lbl.png
# transfer name from bochum_000000_008162_leftImg8bit.png to train_00097_ori.png
# transfer name from bochum_000000_037829_gtFine_labelIds.png to train_00098_lbl.png
# transfer name from bochum_000000_037829_leftImg8bit.png to train_00098_ori.png
# transfer name from bochum_000000_026634_gtFine_labelIds.png to train_00099_lbl.png
# transfer name from bochum_000000_026634_leftImg8bit.png to train_00099_ori.png
# transfer name from bochum_000000_004032_gtFine_labelIds.png to train_00100_lbl.png
# transfer name from bochum_000000_004032_leftImg8bit.png to train_00100_ori.png
# transfer name from bochum_000000_029721_gtFine_labelIds.png to train_00101_lbl.png
# transfer name from bochum_000000_029721_leftImg8bit.png to train_00101_ori.png
# transfer name from bochum_000000_000313_gtFine_labelIds.png to train_00102_lbl.png
# transfer name from bochum_000000_000313_leftImg8bit.png to train_00102_ori.png
# transfer name from bochum_000000_018195_gtFine_labelIds.png to train_00103_lbl.png
# transfer name from bochum_000000_018195_leftImg8bit.png to train_00103_ori.png
# transfer name from bochum_000000_016591_gtFine_labelIds.png to train_00104_lbl.png
# transfer name from bochum_000000_016591_leftImg8bit.png to train_00104_ori.png
# transfer name from bochum_000000_006746_gtFine_labelIds.png to train_00105_lbl.png
# transfer name from bochum_000000_006746_leftImg8bit.png to train_00105_ori.png
# transfer name from bochum_000000_008448_gtFine_labelIds.png to train_00106_lbl.png
# transfer name from bochum_000000_008448_leftImg8bit.png to train_00106_ori.png
# transfer name from bochum_000000_005537_gtFine_labelIds.png to train_00107_lbl.png
# transfer name from bochum_000000_005537_leftImg8bit.png to train_00107_ori.png
# transfer name from bochum_000000_006026_gtFine_labelIds.png to train_00108_lbl.png
# transfer name from bochum_000000_006026_leftImg8bit.png to train_00108_ori.png
# transfer name from bochum_000000_010562_gtFine_labelIds.png to train_00109_lbl.png
# transfer name from bochum_000000_010562_leftImg8bit.png to train_00109_ori.png
# transfer name from bochum_000000_024855_gtFine_labelIds.png to train_00110_lbl.png
# transfer name from bochum_000000_024855_leftImg8bit.png to train_00110_ori.png
# transfer name from bochum_000000_014332_gtFine_labelIds.png to train_00111_lbl.png
# transfer name from bochum_000000_014332_leftImg8bit.png to train_00111_ori.png
# transfer name from bochum_000000_030913_gtFine_labelIds.png to train_00112_lbl.png
# transfer name from bochum_000000_030913_leftImg8bit.png to train_00112_ori.png
# transfer name from bochum_000000_004748_gtFine_labelIds.png to train_00113_lbl.png
# transfer name from bochum_000000_004748_leftImg8bit.png to train_00113_ori.png
# transfer name from bochum_000000_001097_gtFine_labelIds.png to train_00114_lbl.png
# transfer name from bochum_000000_001097_leftImg8bit.png to train_00114_ori.png
# transfer name from bochum_000000_003005_gtFine_labelIds.png to train_00115_lbl.png
# transfer name from bochum_000000_003005_leftImg8bit.png to train_00115_ori.png
# transfer name from bochum_000000_031477_gtFine_labelIds.png to train_00116_lbl.png
# transfer name from bochum_000000_031477_leftImg8bit.png to train_00116_ori.png
# transfer name from bochum_000000_001519_gtFine_labelIds.png to train_00117_lbl.png
# transfer name from bochum_000000_001519_leftImg8bit.png to train_00117_ori.png
# transfer name from bochum_000000_028764_gtFine_labelIds.png to train_00118_lbl.png
# transfer name from bochum_000000_028764_leftImg8bit.png to train_00118_ori.png
# transfer name from bochum_000000_000885_gtFine_labelIds.png to train_00119_lbl.png
# transfer name from bochum_000000_000885_leftImg8bit.png to train_00119_ori.png
# transfer name from bochum_000000_015321_gtFine_labelIds.png to train_00120_lbl.png
# transfer name from bochum_000000_015321_leftImg8bit.png to train_00120_ori.png
# transfer name from bochum_000000_007950_gtFine_labelIds.png to train_00121_lbl.png
# transfer name from bochum_000000_007950_leftImg8bit.png to train_00121_ori.png
# transfer name from bochum_000000_006484_gtFine_labelIds.png to train_00122_lbl.png
# transfer name from bochum_000000_006484_leftImg8bit.png to train_00122_ori.png
# transfer name from bochum_000000_001828_gtFine_labelIds.png to train_00123_lbl.png
# transfer name from bochum_000000_001828_leftImg8bit.png to train_00123_ori.png
# transfer name from bochum_000000_028297_gtFine_labelIds.png to train_00124_lbl.png
# transfer name from bochum_000000_028297_leftImg8bit.png to train_00124_ori.png
# transfer name from bochum_000000_033331_gtFine_labelIds.png to train_00125_lbl.png
# transfer name from bochum_000000_033331_leftImg8bit.png to train_00125_ori.png
# transfer name from bochum_000000_014803_gtFine_labelIds.png to train_00126_lbl.png
# transfer name from bochum_000000_014803_leftImg8bit.png to train_00126_ori.png
# transfer name from bochum_000000_008804_gtFine_labelIds.png to train_00127_lbl.png
# transfer name from bochum_000000_008804_leftImg8bit.png to train_00127_ori.png
# transfer name from bochum_000000_023648_gtFine_labelIds.png to train_00128_lbl.png
# transfer name from bochum_000000_023648_leftImg8bit.png to train_00128_ori.png
# transfer name from bochum_000000_016260_gtFine_labelIds.png to train_00129_lbl.png
# transfer name from bochum_000000_016260_leftImg8bit.png to train_00129_ori.png
# transfer name from bochum_000000_037223_gtFine_labelIds.png to train_00130_lbl.png
# transfer name from bochum_000000_037223_leftImg8bit.png to train_00130_ori.png
# transfer name from bochum_000000_027057_gtFine_labelIds.png to train_00131_lbl.png
# transfer name from bochum_000000_027057_leftImg8bit.png to train_00131_ori.png
# transfer name from bochum_000000_003245_gtFine_labelIds.png to train_00132_lbl.png
# transfer name from bochum_000000_003245_leftImg8bit.png to train_00132_ori.png
# transfer name from bochum_000000_031687_gtFine_labelIds.png to train_00133_lbl.png
# transfer name from bochum_000000_031687_leftImg8bit.png to train_00133_ori.png
# transfer name from bochum_000000_038150_gtFine_labelIds.png to train_00134_lbl.png
# transfer name from bochum_000000_038150_leftImg8bit.png to train_00134_ori.png
# transfer name from bochum_000000_033531_gtFine_labelIds.png to train_00135_lbl.png
# transfer name from bochum_000000_033531_leftImg8bit.png to train_00135_ori.png
# transfer name from bochum_000000_021070_gtFine_labelIds.png to train_00136_lbl.png
# transfer name from bochum_000000_021070_leftImg8bit.png to train_00136_ori.png
# transfer name from bochum_000000_013209_gtFine_labelIds.png to train_00137_lbl.png
# transfer name from bochum_000000_013209_leftImg8bit.png to train_00137_ori.png
# transfer name from bochum_000000_033714_gtFine_labelIds.png to train_00138_lbl.png
# transfer name from bochum_000000_033714_leftImg8bit.png to train_00138_ori.png
# transfer name from bochum_000000_022210_gtFine_labelIds.png to train_00139_lbl.png
# transfer name from bochum_000000_022210_leftImg8bit.png to train_00139_ori.png
# transfer name from bochum_000000_033056_gtFine_labelIds.png to train_00140_lbl.png
# transfer name from bochum_000000_033056_leftImg8bit.png to train_00140_ori.png
# transfer name from bochum_000000_017216_gtFine_labelIds.png to train_00141_lbl.png
# transfer name from bochum_000000_017216_leftImg8bit.png to train_00141_ori.png
# transfer name from bochum_000000_032169_gtFine_labelIds.png to train_00142_lbl.png
# transfer name from bochum_000000_032169_leftImg8bit.png to train_00142_ori.png
# transfer name from bochum_000000_003674_gtFine_labelIds.png to train_00143_lbl.png
# transfer name from bochum_000000_003674_leftImg8bit.png to train_00143_ori.png
# transfer name from bochum_000000_029203_gtFine_labelIds.png to train_00144_lbl.png
# transfer name from bochum_000000_029203_leftImg8bit.png to train_00144_ori.png
# transfer name from bochum_000000_005936_gtFine_labelIds.png to train_00145_lbl.png
# transfer name from bochum_000000_005936_leftImg8bit.png to train_00145_ori.png
# transfer name from bochum_000000_002562_gtFine_labelIds.png to train_00146_lbl.png
# transfer name from bochum_000000_002562_leftImg8bit.png to train_00146_ori.png
# transfer name from bochum_000000_038022_gtFine_labelIds.png to train_00147_lbl.png
# transfer name from bochum_000000_038022_leftImg8bit.png to train_00147_ori.png
# transfer name from bochum_000000_021325_gtFine_labelIds.png to train_00148_lbl.png
# transfer name from bochum_000000_021325_leftImg8bit.png to train_00148_ori.png
# transfer name from bochum_000000_021606_gtFine_labelIds.png to train_00149_lbl.png
# transfer name from bochum_000000_021606_leftImg8bit.png to train_00149_ori.png
# transfer name from bochum_000000_013705_gtFine_labelIds.png to train_00150_lbl.png
# transfer name from bochum_000000_013705_leftImg8bit.png to train_00150_ori.png
# transfer name from bochum_000000_036606_gtFine_labelIds.png to train_00151_lbl.png
# transfer name from bochum_000000_036606_leftImg8bit.png to train_00151_ori.png
# transfer name from bochum_000000_024196_gtFine_labelIds.png to train_00152_lbl.png
# transfer name from bochum_000000_024196_leftImg8bit.png to train_00152_ori.png
# transfer name from bochum_000000_025746_gtFine_labelIds.png to train_00153_lbl.png
# transfer name from bochum_000000_025746_leftImg8bit.png to train_00153_ori.png
# transfer name from bochum_000000_020776_gtFine_labelIds.png to train_00154_lbl.png
# transfer name from bochum_000000_020776_leftImg8bit.png to train_00154_ori.png
# transfer name from bochum_000000_002293_gtFine_labelIds.png to train_00155_lbl.png
# transfer name from bochum_000000_002293_leftImg8bit.png to train_00155_ori.png
# transfer name from bochum_000000_023435_gtFine_labelIds.png to train_00156_lbl.png
# transfer name from bochum_000000_023435_leftImg8bit.png to train_00156_ori.png
# transfer name from bochum_000000_016758_gtFine_labelIds.png to train_00157_lbl.png
# transfer name from bochum_000000_016758_leftImg8bit.png to train_00157_ori.png
# transfer name from bochum_000000_015880_gtFine_labelIds.png to train_00158_lbl.png
# transfer name from bochum_000000_015880_leftImg8bit.png to train_00158_ori.png
# transfer name from bochum_000000_015645_gtFine_labelIds.png to train_00159_lbl.png
# transfer name from bochum_000000_015645_leftImg8bit.png to train_00159_ori.png
# transfer name from bochum_000000_034936_gtFine_labelIds.png to train_00160_lbl.png
# transfer name from bochum_000000_034936_leftImg8bit.png to train_00160_ori.png
# transfer name from bochum_000000_017453_gtFine_labelIds.png to train_00161_lbl.png
# transfer name from bochum_000000_017453_leftImg8bit.png to train_00161_ori.png
# transfer name from bochum_000000_024524_gtFine_labelIds.png to train_00162_lbl.png
# transfer name from bochum_000000_024524_leftImg8bit.png to train_00162_ori.png
# transfer name from bochum_000000_024717_gtFine_labelIds.png to train_00163_lbl.png
# transfer name from bochum_000000_024717_leftImg8bit.png to train_00163_ori.png
# transfer name from bochum_000000_022414_gtFine_labelIds.png to train_00164_lbl.png
# transfer name from bochum_000000_022414_leftImg8bit.png to train_00164_ori.png
# transfer name from bochum_000000_011711_gtFine_labelIds.png to train_00165_lbl.png
# transfer name from bochum_000000_011711_leftImg8bit.png to train_00165_ori.png
# transfer name from bochum_000000_035958_gtFine_labelIds.png to train_00166_lbl.png
# transfer name from bochum_000000_035958_leftImg8bit.png to train_00166_ori.png
# transfer name from bochum_000000_023040_gtFine_labelIds.png to train_00167_lbl.png
# transfer name from bochum_000000_023040_leftImg8bit.png to train_00167_ori.png
# transfer name from bochum_000000_021479_gtFine_labelIds.png to train_00168_lbl.png
# transfer name from bochum_000000_021479_leftImg8bit.png to train_00168_ori.png
# transfer name from bochum_000000_011255_gtFine_labelIds.png to train_00169_lbl.png
# transfer name from bochum_000000_011255_leftImg8bit.png to train_00169_ori.png
# transfer name from bochum_000000_031152_gtFine_labelIds.png to train_00170_lbl.png
# transfer name from bochum_000000_031152_leftImg8bit.png to train_00170_ori.png
# transfer name from bochum_000000_024343_gtFine_labelIds.png to train_00171_lbl.png
# transfer name from bochum_000000_024343_leftImg8bit.png to train_00171_ori.png
# transfer name from bochum_000000_025833_gtFine_labelIds.png to train_00172_lbl.png
# transfer name from bochum_000000_025833_leftImg8bit.png to train_00172_ori.png
# transfer name from bochum_000000_026056_gtFine_labelIds.png to train_00173_lbl.png
# transfer name from bochum_000000_026056_leftImg8bit.png to train_00173_ori.png
# transfer name from bochum_000000_037039_gtFine_labelIds.png to train_00174_lbl.png
# transfer name from bochum_000000_037039_leftImg8bit.png to train_00174_ori.png
# transfer name from bochum_000000_016125_gtFine_labelIds.png to train_00175_lbl.png
# transfer name from bochum_000000_016125_leftImg8bit.png to train_00175_ori.png
# transfer name from bochum_000000_014658_gtFine_labelIds.png to train_00176_lbl.png
# transfer name from bochum_000000_014658_leftImg8bit.png to train_00176_ori.png
# transfer name from bochum_000000_000600_gtFine_labelIds.png to train_00177_lbl.png
# transfer name from bochum_000000_000600_leftImg8bit.png to train_00177_ori.png
# transfer name from bochum_000000_015038_gtFine_labelIds.png to train_00178_lbl.png
# transfer name from bochum_000000_015038_leftImg8bit.png to train_00178_ori.png
# transfer name from bochum_000000_007150_gtFine_labelIds.png to train_00179_lbl.png
# transfer name from bochum_000000_007150_leftImg8bit.png to train_00179_ori.png
# transfer name from bochum_000000_009554_gtFine_labelIds.png to train_00180_lbl.png
# transfer name from bochum_000000_009554_leftImg8bit.png to train_00180_ori.png
# transfer name from hanover_000000_037039_gtFine_labelIds.png to train_00181_lbl.png
# transfer name from hanover_000000_037039_leftImg8bit.png to train_00181_ori.png
# transfer name from hanover_000000_035606_gtFine_labelIds.png to train_00182_lbl.png
# transfer name from hanover_000000_035606_leftImg8bit.png to train_00182_ori.png
# transfer name from hanover_000000_050228_gtFine_labelIds.png to train_00183_lbl.png
# transfer name from hanover_000000_050228_leftImg8bit.png to train_00183_ori.png
# transfer name from hanover_000000_019456_gtFine_labelIds.png to train_00184_lbl.png
# transfer name from hanover_000000_019456_leftImg8bit.png to train_00184_ori.png
# transfer name from hanover_000000_020089_gtFine_labelIds.png to train_00185_lbl.png
# transfer name from hanover_000000_020089_leftImg8bit.png to train_00185_ori.png
# transfer name from hanover_000000_003224_gtFine_labelIds.png to train_00186_lbl.png
# transfer name from hanover_000000_003224_leftImg8bit.png to train_00186_ori.png
# transfer name from hanover_000000_029325_gtFine_labelIds.png to train_00187_lbl.png
# transfer name from hanover_000000_029325_leftImg8bit.png to train_00187_ori.png
# transfer name from hanover_000000_009128_gtFine_labelIds.png to train_00188_lbl.png
# transfer name from hanover_000000_009128_leftImg8bit.png to train_00188_ori.png
# transfer name from hanover_000000_052729_gtFine_labelIds.png to train_00189_lbl.png
# transfer name from hanover_000000_052729_leftImg8bit.png to train_00189_ori.png
# transfer name from hanover_000000_046200_gtFine_labelIds.png to train_00190_lbl.png
# transfer name from hanover_000000_046200_leftImg8bit.png to train_00190_ori.png
# transfer name from hanover_000000_008017_gtFine_labelIds.png to train_00191_lbl.png
# transfer name from hanover_000000_008017_leftImg8bit.png to train_00191_ori.png
# transfer name from hanover_000000_005175_gtFine_labelIds.png to train_00192_lbl.png
# transfer name from hanover_000000_005175_leftImg8bit.png to train_00192_ori.png
# transfer name from hanover_000000_024136_gtFine_labelIds.png to train_00193_lbl.png
# transfer name from hanover_000000_024136_leftImg8bit.png to train_00193_ori.png
# transfer name from hanover_000000_017041_gtFine_labelIds.png to train_00194_lbl.png
# transfer name from hanover_000000_017041_leftImg8bit.png to train_00194_ori.png
# transfer name from hanover_000000_035491_gtFine_labelIds.png to train_00195_lbl.png
# transfer name from hanover_000000_035491_leftImg8bit.png to train_00195_ori.png
# transfer name from hanover_000000_057710_gtFine_labelIds.png to train_00196_lbl.png
# transfer name from hanover_000000_057710_leftImg8bit.png to train_00196_ori.png
# transfer name from hanover_000000_054276_gtFine_labelIds.png to train_00197_lbl.png
# transfer name from hanover_000000_054276_leftImg8bit.png to train_00197_ori.png
# transfer name from hanover_000000_014713_gtFine_labelIds.png to train_00198_lbl.png
# transfer name from hanover_000000_014713_leftImg8bit.png to train_00198_ori.png
# transfer name from hanover_000000_030276_gtFine_labelIds.png to train_00199_lbl.png
# transfer name from hanover_000000_030276_leftImg8bit.png to train_00199_ori.png
# transfer name from hanover_000000_045657_gtFine_labelIds.png to train_00200_lbl.png
# transfer name from hanover_000000_045657_leftImg8bit.png to train_00200_ori.png
# transfer name from hanover_000000_034015_gtFine_labelIds.png to train_00201_lbl.png
# transfer name from hanover_000000_034015_leftImg8bit.png to train_00201_ori.png
# transfer name from hanover_000000_009004_gtFine_labelIds.png to train_00202_lbl.png
# transfer name from hanover_000000_009004_leftImg8bit.png to train_00202_ori.png
# transfer name from hanover_000000_027561_gtFine_labelIds.png to train_00203_lbl.png
# transfer name from hanover_000000_027561_leftImg8bit.png to train_00203_ori.png
# transfer name from hanover_000000_013094_gtFine_labelIds.png to train_00204_lbl.png
# transfer name from hanover_000000_013094_leftImg8bit.png to train_00204_ori.png
# transfer name from hanover_000000_005288_gtFine_labelIds.png to train_00205_lbl.png
# transfer name from hanover_000000_005288_leftImg8bit.png to train_00205_ori.png
# transfer name from hanover_000000_032559_gtFine_labelIds.png to train_00206_lbl.png
# transfer name from hanover_000000_032559_leftImg8bit.png to train_00206_ori.png
# transfer name from hanover_000000_056142_gtFine_labelIds.png to train_00207_lbl.png
# transfer name from hanover_000000_056142_leftImg8bit.png to train_00207_ori.png
# transfer name from hanover_000000_000164_gtFine_labelIds.png to train_00208_lbl.png
# transfer name from hanover_000000_000164_leftImg8bit.png to train_00208_ori.png
# transfer name from hanover_000000_007342_gtFine_labelIds.png to train_00209_lbl.png
# transfer name from hanover_000000_007342_leftImg8bit.png to train_00209_ori.png
# transfer name from hanover_000000_051536_gtFine_labelIds.png to train_00210_lbl.png
# transfer name from hanover_000000_051536_leftImg8bit.png to train_00210_ori.png
# transfer name from hanover_000000_048508_gtFine_labelIds.png to train_00211_lbl.png
# transfer name from hanover_000000_048508_leftImg8bit.png to train_00211_ori.png
# transfer name from hanover_000000_030889_gtFine_labelIds.png to train_00212_lbl.png
# transfer name from hanover_000000_030889_leftImg8bit.png to train_00212_ori.png
# transfer name from hanover_000000_024989_gtFine_labelIds.png to train_00213_lbl.png
# transfer name from hanover_000000_024989_leftImg8bit.png to train_00213_ori.png
# transfer name from hanover_000000_029455_gtFine_labelIds.png to train_00214_lbl.png
# transfer name from hanover_000000_029455_leftImg8bit.png to train_00214_ori.png
# transfer name from hanover_000000_047629_gtFine_labelIds.png to train_00215_lbl.png
# transfer name from hanover_000000_047629_leftImg8bit.png to train_00215_ori.png
# transfer name from hanover_000000_007780_gtFine_labelIds.png to train_00216_lbl.png
# transfer name from hanover_000000_007780_leftImg8bit.png to train_00216_ori.png
# transfer name from hanover_000000_028460_gtFine_labelIds.png to train_00217_lbl.png
# transfer name from hanover_000000_028460_leftImg8bit.png to train_00217_ori.png
# transfer name from hanover_000000_018546_gtFine_labelIds.png to train_00218_lbl.png
# transfer name from hanover_000000_018546_leftImg8bit.png to train_00218_ori.png
# transfer name from hanover_000000_024719_gtFine_labelIds.png to train_00219_lbl.png
# transfer name from hanover_000000_024719_leftImg8bit.png to train_00219_ori.png
# transfer name from hanover_000000_027390_gtFine_labelIds.png to train_00220_lbl.png
# transfer name from hanover_000000_027390_leftImg8bit.png to train_00220_ori.png
# transfer name from hanover_000000_003411_gtFine_labelIds.png to train_00221_lbl.png
# transfer name from hanover_000000_003411_leftImg8bit.png to train_00221_ori.png
# transfer name from hanover_000000_049465_gtFine_labelIds.png to train_00222_lbl.png
# transfer name from hanover_000000_049465_leftImg8bit.png to train_00222_ori.png
# transfer name from hanover_000000_006922_gtFine_labelIds.png to train_00223_lbl.png
# transfer name from hanover_000000_006922_leftImg8bit.png to train_00223_ori.png
# transfer name from hanover_000000_039021_gtFine_labelIds.png to train_00224_lbl.png
# transfer name from hanover_000000_039021_leftImg8bit.png to train_00224_ori.png
# transfer name from hanover_000000_030781_gtFine_labelIds.png to train_00225_lbl.png
# transfer name from hanover_000000_030781_leftImg8bit.png to train_00225_ori.png
# transfer name from hanover_000000_033457_gtFine_labelIds.png to train_00226_lbl.png
# transfer name from hanover_000000_033457_leftImg8bit.png to train_00226_ori.png
# transfer name from hanover_000000_019672_gtFine_labelIds.png to train_00227_lbl.png
# transfer name from hanover_000000_019672_leftImg8bit.png to train_00227_ori.png
# transfer name from hanover_000000_016038_gtFine_labelIds.png to train_00228_lbl.png
# transfer name from hanover_000000_016038_leftImg8bit.png to train_00228_ori.png
# transfer name from hanover_000000_038773_gtFine_labelIds.png to train_00229_lbl.png
# transfer name from hanover_000000_038773_leftImg8bit.png to train_00229_ori.png
# transfer name from hanover_000000_026014_gtFine_labelIds.png to train_00230_lbl.png
# transfer name from hanover_000000_026014_leftImg8bit.png to train_00230_ori.png
# transfer name from hanover_000000_040051_gtFine_labelIds.png to train_00231_lbl.png
# transfer name from hanover_000000_040051_leftImg8bit.png to train_00231_ori.png
# transfer name from hanover_000000_029043_gtFine_labelIds.png to train_00232_lbl.png
# transfer name from hanover_000000_029043_leftImg8bit.png to train_00232_ori.png
# transfer name from hanover_000000_045841_gtFine_labelIds.png to train_00233_lbl.png
# transfer name from hanover_000000_045841_leftImg8bit.png to train_00233_ori.png
# transfer name from hanover_000000_056457_gtFine_labelIds.png to train_00234_lbl.png
# transfer name from hanover_000000_056457_leftImg8bit.png to train_00234_ori.png
# transfer name from hanover_000000_050398_gtFine_labelIds.png to train_00235_lbl.png
# transfer name from hanover_000000_050398_leftImg8bit.png to train_00235_ori.png
# transfer name from hanover_000000_012675_gtFine_labelIds.png to train_00236_lbl.png
# transfer name from hanover_000000_012675_leftImg8bit.png to train_00236_ori.png
# transfer name from hanover_000000_025437_gtFine_labelIds.png to train_00237_lbl.png
# transfer name from hanover_000000_025437_leftImg8bit.png to train_00237_ori.png
# transfer name from hanover_000000_054965_gtFine_labelIds.png to train_00238_lbl.png
# transfer name from hanover_000000_054965_leftImg8bit.png to train_00238_ori.png
# transfer name from hanover_000000_051842_gtFine_labelIds.png to train_00239_lbl.png
# transfer name from hanover_000000_051842_leftImg8bit.png to train_00239_ori.png
# transfer name from hanover_000000_001173_gtFine_labelIds.png to train_00240_lbl.png
# transfer name from hanover_000000_001173_leftImg8bit.png to train_00240_ori.png
# transfer name from hanover_000000_006355_gtFine_labelIds.png to train_00241_lbl.png
# transfer name from hanover_000000_006355_leftImg8bit.png to train_00241_ori.png
# transfer name from hanover_000000_047870_gtFine_labelIds.png to train_00242_lbl.png
# transfer name from hanover_000000_047870_leftImg8bit.png to train_00242_ori.png
# transfer name from hanover_000000_040294_gtFine_labelIds.png to train_00243_lbl.png
# transfer name from hanover_000000_040294_leftImg8bit.png to train_00243_ori.png
# transfer name from hanover_000000_042770_gtFine_labelIds.png to train_00244_lbl.png
# transfer name from hanover_000000_042770_leftImg8bit.png to train_00244_ori.png
# transfer name from hanover_000000_034720_gtFine_labelIds.png to train_00245_lbl.png
# transfer name from hanover_000000_034720_leftImg8bit.png to train_00245_ori.png
# transfer name from hanover_000000_045446_gtFine_labelIds.png to train_00246_lbl.png
# transfer name from hanover_000000_045446_leftImg8bit.png to train_00246_ori.png
# transfer name from hanover_000000_002357_gtFine_labelIds.png to train_00247_lbl.png
# transfer name from hanover_000000_002357_leftImg8bit.png to train_00247_ori.png
# transfer name from hanover_000000_014537_gtFine_labelIds.png to train_00248_lbl.png
# transfer name from hanover_000000_014537_leftImg8bit.png to train_00248_ori.png
# transfer name from hanover_000000_015849_gtFine_labelIds.png to train_00249_lbl.png
# transfer name from hanover_000000_015849_leftImg8bit.png to train_00249_ori.png
# transfer name from hanover_000000_019116_gtFine_labelIds.png to train_00250_lbl.png
# transfer name from hanover_000000_019116_leftImg8bit.png to train_00250_ori.png
# transfer name from hanover_000000_034935_gtFine_labelIds.png to train_00251_lbl.png
# transfer name from hanover_000000_034935_leftImg8bit.png to train_00251_ori.png
# transfer name from hanover_000000_029404_gtFine_labelIds.png to train_00252_lbl.png
# transfer name from hanover_000000_029404_leftImg8bit.png to train_00252_ori.png
# transfer name from hanover_000000_041610_gtFine_labelIds.png to train_00253_lbl.png
# transfer name from hanover_000000_041610_leftImg8bit.png to train_00253_ori.png
# transfer name from hanover_000000_056361_gtFine_labelIds.png to train_00254_lbl.png
# transfer name from hanover_000000_056361_leftImg8bit.png to train_00254_ori.png
# transfer name from hanover_000000_013814_gtFine_labelIds.png to train_00255_lbl.png
# transfer name from hanover_000000_013814_leftImg8bit.png to train_00255_ori.png
# transfer name from hanover_000000_055937_gtFine_labelIds.png to train_00256_lbl.png
# transfer name from hanover_000000_055937_leftImg8bit.png to train_00256_ori.png
# transfer name from hanover_000000_024276_gtFine_labelIds.png to train_00257_lbl.png
# transfer name from hanover_000000_024276_leftImg8bit.png to train_00257_ori.png
# transfer name from hanover_000000_003853_gtFine_labelIds.png to train_00258_lbl.png
# transfer name from hanover_000000_003853_leftImg8bit.png to train_00258_ori.png
# transfer name from hanover_000000_041493_gtFine_labelIds.png to train_00259_lbl.png
# transfer name from hanover_000000_041493_leftImg8bit.png to train_00259_ori.png
# transfer name from hanover_000000_019282_gtFine_labelIds.png to train_00260_lbl.png
# transfer name from hanover_000000_019282_leftImg8bit.png to train_00260_ori.png
# transfer name from hanover_000000_015587_gtFine_labelIds.png to train_00261_lbl.png
# transfer name from hanover_000000_015587_leftImg8bit.png to train_00261_ori.png
# transfer name from hanover_000000_027007_gtFine_labelIds.png to train_00262_lbl.png
# transfer name from hanover_000000_027007_leftImg8bit.png to train_00262_ori.png
# transfer name from hanover_000000_009420_gtFine_labelIds.png to train_00263_lbl.png
# transfer name from hanover_000000_009420_leftImg8bit.png to train_00263_ori.png
# transfer name from hanover_000000_053027_gtFine_labelIds.png to train_00264_lbl.png
# transfer name from hanover_000000_053027_leftImg8bit.png to train_00264_ori.png
# transfer name from hanover_000000_035768_gtFine_labelIds.png to train_00265_lbl.png
# transfer name from hanover_000000_035768_leftImg8bit.png to train_00265_ori.png
# transfer name from hanover_000000_038927_gtFine_labelIds.png to train_00266_lbl.png
# transfer name from hanover_000000_038927_leftImg8bit.png to train_00266_ori.png
# transfer name from hanover_000000_032681_gtFine_labelIds.png to train_00267_lbl.png
# transfer name from hanover_000000_032681_leftImg8bit.png to train_00267_ori.png
# transfer name from hanover_000000_023881_gtFine_labelIds.png to train_00268_lbl.png
# transfer name from hanover_000000_023881_leftImg8bit.png to train_00268_ori.png
# transfer name from hanover_000000_037298_gtFine_labelIds.png to train_00269_lbl.png
# transfer name from hanover_000000_037298_leftImg8bit.png to train_00269_ori.png
# transfer name from hanover_000000_010403_gtFine_labelIds.png to train_00270_lbl.png
# transfer name from hanover_000000_010403_leftImg8bit.png to train_00270_ori.png
# transfer name from hanover_000000_019938_gtFine_labelIds.png to train_00271_lbl.png
# transfer name from hanover_000000_019938_leftImg8bit.png to train_00271_ori.png
# transfer name from hanover_000000_052649_gtFine_labelIds.png to train_00272_lbl.png
# transfer name from hanover_000000_052649_leftImg8bit.png to train_00272_ori.png
# transfer name from hanover_000000_005970_gtFine_labelIds.png to train_00273_lbl.png
# transfer name from hanover_000000_005970_leftImg8bit.png to train_00273_ori.png
# transfer name from hanover_000000_034560_gtFine_labelIds.png to train_00274_lbl.png
# transfer name from hanover_000000_034560_leftImg8bit.png to train_00274_ori.png
# transfer name from hanover_000000_018800_gtFine_labelIds.png to train_00275_lbl.png
# transfer name from hanover_000000_018800_leftImg8bit.png to train_00275_ori.png
# transfer name from hanover_000000_046398_gtFine_labelIds.png to train_00276_lbl.png
# transfer name from hanover_000000_046398_leftImg8bit.png to train_00276_ori.png
# transfer name from hanover_000000_058189_gtFine_labelIds.png to train_00277_lbl.png
# transfer name from hanover_000000_058189_leftImg8bit.png to train_00277_ori.png
# transfer name from hanover_000000_051059_gtFine_labelIds.png to train_00278_lbl.png
# transfer name from hanover_000000_051059_leftImg8bit.png to train_00278_ori.png
# transfer name from hanover_000000_043550_gtFine_labelIds.png to train_00279_lbl.png
# transfer name from hanover_000000_043550_leftImg8bit.png to train_00279_ori.png
# transfer name from hanover_000000_018213_gtFine_labelIds.png to train_00280_lbl.png
# transfer name from hanover_000000_018213_leftImg8bit.png to train_00280_ori.png
# transfer name from hanover_000000_044622_gtFine_labelIds.png to train_00281_lbl.png
# transfer name from hanover_000000_044622_leftImg8bit.png to train_00281_ori.png
# transfer name from hanover_000000_013205_gtFine_labelIds.png to train_00282_lbl.png
# transfer name from hanover_000000_013205_leftImg8bit.png to train_00282_ori.png
# transfer name from hanover_000000_032351_gtFine_labelIds.png to train_00283_lbl.png
# transfer name from hanover_000000_032351_leftImg8bit.png to train_00283_ori.png
# transfer name from hanover_000000_027481_gtFine_labelIds.png to train_00284_lbl.png
# transfer name from hanover_000000_027481_leftImg8bit.png to train_00284_ori.png
# transfer name from hanover_000000_011971_gtFine_labelIds.png to train_00285_lbl.png
# transfer name from hanover_000000_011971_leftImg8bit.png to train_00285_ori.png
# transfer name from hanover_000000_049005_gtFine_labelIds.png to train_00286_lbl.png
# transfer name from hanover_000000_049005_leftImg8bit.png to train_00286_ori.png
# transfer name from hanover_000000_027650_gtFine_labelIds.png to train_00287_lbl.png
# transfer name from hanover_000000_027650_leftImg8bit.png to train_00287_ori.png
# transfer name from hanover_000000_027998_gtFine_labelIds.png to train_00288_lbl.png
# transfer name from hanover_000000_027998_leftImg8bit.png to train_00288_ori.png
# transfer name from hanover_000000_052887_gtFine_labelIds.png to train_00289_lbl.png
# transfer name from hanover_000000_052887_leftImg8bit.png to train_00289_ori.png
# transfer name from hanover_000000_002140_gtFine_labelIds.png to train_00290_lbl.png
# transfer name from hanover_000000_002140_leftImg8bit.png to train_00290_ori.png
# transfer name from hanover_000000_026804_gtFine_labelIds.png to train_00291_lbl.png
# ...
# transfer name from berlin_000219_000019_gtFine_labelIds.png to test_01425_lbl.png
# transfer name from berlin_000219_000019_leftImg8bit.png to test_01425_ori.png
# transfer name from berlin_000173_000019_gtFine_labelIds.png to test_01426_lbl.png
# transfer name from berlin_000173_000019_leftImg8bit.png to test_01426_ori.png
# transfer name from berlin_000414_000019_gtFine_labelIds.png to test_01427_lbl.png
# transfer name from berlin_000414_000019_leftImg8bit.png to test_01427_ori.png
# transfer name from berlin_000344_000019_gtFine_labelIds.png to test_01428_lbl.png
# transfer name from berlin_000344_000019_leftImg8bit.png to test_01428_ori.png
# transfer name from berlin_000285_000019_gtFine_labelIds.png to test_01429_lbl.png
# transfer name from berlin_000285_000019_leftImg8bit.png to test_01429_ori.png
# transfer name from berlin_000239_000019_gtFine_labelIds.png to test_01430_lbl.png
# transfer name from berlin_000239_000019_leftImg8bit.png to test_01430_ori.png
# transfer name from berlin_000107_000019_gtFine_labelIds.png to test_01431_lbl.png
# transfer name from berlin_000107_000019_leftImg8bit.png to test_01431_ori.png
# transfer name from berlin_000460_000019_gtFine_labelIds.png to test_01432_lbl.png
# transfer name from berlin_000460_000019_leftImg8bit.png to test_01432_ori.png
# transfer name from berlin_000330_000019_gtFine_labelIds.png to test_01433_lbl.png
# transfer name from berlin_000330_000019_leftImg8bit.png to test_01433_ori.png
# transfer name from berlin_000167_000019_gtFine_labelIds.png to test_01434_lbl.png
# transfer name from berlin_000167_000019_leftImg8bit.png to test_01434_ori.png
# transfer name from berlin_000400_000019_gtFine_labelIds.png to test_01435_lbl.png
# transfer name from berlin_000400_000019_leftImg8bit.png to test_01435_ori.png
# transfer name from berlin_000350_000019_gtFine_labelIds.png to test_01436_lbl.png
# transfer name from berlin_000350_000019_leftImg8bit.png to test_01436_ori.png
# transfer name from berlin_000259_000019_gtFine_labelIds.png to test_01437_lbl.png
# transfer name from berlin_000259_000019_leftImg8bit.png to test_01437_ori.png
# transfer name from berlin_000509_000019_gtFine_labelIds.png to test_01438_lbl.png
# transfer name from berlin_000509_000019_leftImg8bit.png to test_01438_ori.png
# transfer name from berlin_000291_000019_gtFine_labelIds.png to test_01439_lbl.png
# transfer name from berlin_000291_000019_leftImg8bit.png to test_01439_ori.png
# transfer name from berlin_000113_000019_gtFine_labelIds.png to test_01440_lbl.png
# transfer name from berlin_000113_000019_leftImg8bit.png to test_01440_ori.png
# transfer name from berlin_000474_000019_gtFine_labelIds.png to test_01441_lbl.png
# transfer name from berlin_000474_000019_leftImg8bit.png to test_01441_ori.png
# transfer name from berlin_000398_000019_gtFine_labelIds.png to test_01442_lbl.png
# transfer name from berlin_000398_000019_leftImg8bit.png to test_01442_ori.png
# transfer name from berlin_000324_000019_gtFine_labelIds.png to test_01443_lbl.png
# transfer name from berlin_000324_000019_leftImg8bit.png to test_01443_ori.png
# transfer name from berlin_000279_000019_gtFine_labelIds.png to test_01444_lbl.png
# transfer name from berlin_000279_000019_leftImg8bit.png to test_01444_ori.png
# transfer name from berlin_000529_000019_gtFine_labelIds.png to test_01445_lbl.png
# transfer name from berlin_000529_000019_leftImg8bit.png to test_01445_ori.png
# transfer name from berlin_000147_000019_gtFine_labelIds.png to test_01446_lbl.png
# transfer name from berlin_000147_000019_leftImg8bit.png to test_01446_ori.png
# transfer name from berlin_000420_000019_gtFine_labelIds.png to test_01447_lbl.png
# transfer name from berlin_000420_000019_leftImg8bit.png to test_01447_ori.png
# transfer name from berlin_000370_000019_gtFine_labelIds.png to test_01448_lbl.png
# transfer name from berlin_000370_000019_leftImg8bit.png to test_01448_ori.png
# transfer name from berlin_000133_000019_gtFine_labelIds.png to test_01449_lbl.png
# transfer name from berlin_000133_000019_leftImg8bit.png to test_01449_ori.png
# transfer name from berlin_000454_000019_gtFine_labelIds.png to test_01450_lbl.png
# transfer name from berlin_000454_000019_leftImg8bit.png to test_01450_ori.png
# transfer name from berlin_000304_000019_gtFine_labelIds.png to test_01451_lbl.png
# transfer name from berlin_000304_000019_leftImg8bit.png to test_01451_ori.png
# transfer name from berlin_000086_000019_gtFine_labelIds.png to test_01452_lbl.png
# transfer name from berlin_000086_000019_leftImg8bit.png to test_01452_ori.png
# transfer name from berlin_000365_000019_gtFine_labelIds.png to test_01453_lbl.png
# transfer name from berlin_000365_000019_leftImg8bit.png to test_01453_ori.png
# transfer name from berlin_000435_000019_gtFine_labelIds.png to test_01454_lbl.png
# transfer name from berlin_000435_000019_leftImg8bit.png to test_01454_ori.png
# transfer name from berlin_000489_000019_gtFine_labelIds.png to test_01455_lbl.png
# transfer name from berlin_000489_000019_leftImg8bit.png to test_01455_ori.png
# transfer name from berlin_000152_000019_gtFine_labelIds.png to test_01456_lbl.png
# transfer name from berlin_000152_000019_leftImg8bit.png to test_01456_ori.png
# transfer name from berlin_000218_000019_gtFine_labelIds.png to test_01457_lbl.png
# transfer name from berlin_000218_000019_leftImg8bit.png to test_01457_ori.png
# transfer name from berlin_000093_000019_gtFine_labelIds.png to test_01458_lbl.png
# transfer name from berlin_000093_000019_leftImg8bit.png to test_01458_ori.png
# transfer name from berlin_000311_000019_gtFine_labelIds.png to test_01459_lbl.png
# transfer name from berlin_000311_000019_leftImg8bit.png to test_01459_ori.png
# transfer name from berlin_000441_000019_gtFine_labelIds.png to test_01460_lbl.png
# transfer name from berlin_000441_000019_leftImg8bit.png to test_01460_ori.png
# transfer name from berlin_000126_000019_gtFine_labelIds.png to test_01461_lbl.png
# transfer name from berlin_000126_000019_leftImg8bit.png to test_01461_ori.png
# transfer name from berlin_000345_000019_gtFine_labelIds.png to test_01462_lbl.png
# transfer name from berlin_000345_000019_leftImg8bit.png to test_01462_ori.png
# transfer name from berlin_000415_000019_gtFine_labelIds.png to test_01463_lbl.png
# transfer name from berlin_000415_000019_leftImg8bit.png to test_01463_ori.png
# transfer name from berlin_000172_000019_gtFine_labelIds.png to test_01464_lbl.png
# transfer name from berlin_000172_000019_leftImg8bit.png to test_01464_ori.png
# transfer name from berlin_000331_000019_gtFine_labelIds.png to test_01465_lbl.png
# transfer name from berlin_000331_000019_leftImg8bit.png to test_01465_ori.png
# transfer name from berlin_000461_000019_gtFine_labelIds.png to test_01466_lbl.png
# transfer name from berlin_000461_000019_leftImg8bit.png to test_01466_ori.png
# transfer name from berlin_000106_000019_gtFine_labelIds.png to test_01467_lbl.png
# transfer name from berlin_000106_000019_leftImg8bit.png to test_01467_ori.png
# transfer name from berlin_000238_000019_gtFine_labelIds.png to test_01468_lbl.png
# transfer name from berlin_000238_000019_leftImg8bit.png to test_01468_ori.png
# transfer name from berlin_000284_000019_gtFine_labelIds.png to test_01469_lbl.png
# transfer name from berlin_000284_000019_leftImg8bit.png to test_01469_ori.png
# transfer name from berlin_000508_000019_gtFine_labelIds.png to test_01470_lbl.png
# transfer name from berlin_000508_000019_leftImg8bit.png to test_01470_ori.png
# transfer name from berlin_000258_000019_gtFine_labelIds.png to test_01471_lbl.png
# transfer name from berlin_000258_000019_leftImg8bit.png to test_01471_ori.png
# transfer name from berlin_000351_000019_gtFine_labelIds.png to test_01472_lbl.png
# transfer name from berlin_000351_000019_leftImg8bit.png to test_01472_ori.png
# transfer name from berlin_000401_000019_gtFine_labelIds.png to test_01473_lbl.png
# transfer name from berlin_000401_000019_leftImg8bit.png to test_01473_ori.png
# transfer name from berlin_000166_000019_gtFine_labelIds.png to test_01474_lbl.png
# transfer name from berlin_000166_000019_leftImg8bit.png to test_01474_ori.png
# transfer name from berlin_000325_000019_gtFine_labelIds.png to test_01475_lbl.png
# transfer name from berlin_000325_000019_leftImg8bit.png to test_01475_ori.png
# transfer name from berlin_000399_000019_gtFine_labelIds.png to test_01476_lbl.png
# transfer name from berlin_000399_000019_leftImg8bit.png to test_01476_ori.png
# transfer name from berlin_000475_000019_gtFine_labelIds.png to test_01477_lbl.png
# transfer name from berlin_000475_000019_leftImg8bit.png to test_01477_ori.png
# transfer name from berlin_000112_000019_gtFine_labelIds.png to test_01478_lbl.png
# transfer name from berlin_000112_000019_leftImg8bit.png to test_01478_ori.png
# transfer name from berlin_000290_000019_gtFine_labelIds.png to test_01479_lbl.png
# transfer name from berlin_000290_000019_leftImg8bit.png to test_01479_ori.png
# transfer name from berlin_000371_000019_gtFine_labelIds.png to test_01480_lbl.png
# transfer name from berlin_000371_000019_leftImg8bit.png to test_01480_ori.png
# transfer name from berlin_000421_000019_gtFine_labelIds.png to test_01481_lbl.png
# transfer name from berlin_000421_000019_leftImg8bit.png to test_01481_ori.png
# transfer name from berlin_000146_000019_gtFine_labelIds.png to test_01482_lbl.png
# transfer name from berlin_000146_000019_leftImg8bit.png to test_01482_ori.png
# transfer name from berlin_000528_000019_gtFine_labelIds.png to test_01483_lbl.png
# transfer name from berlin_000528_000019_leftImg8bit.png to test_01483_ori.png
# transfer name from berlin_000278_000019_gtFine_labelIds.png to test_01484_lbl.png
# transfer name from berlin_000278_000019_leftImg8bit.png to test_01484_ori.png
# transfer name from berlin_000087_000019_gtFine_labelIds.png to test_01485_lbl.png
# transfer name from berlin_000087_000019_leftImg8bit.png to test_01485_ori.png
# transfer name from berlin_000305_000019_gtFine_labelIds.png to test_01486_lbl.png
# transfer name from berlin_000305_000019_leftImg8bit.png to test_01486_ori.png
# transfer name from berlin_000455_000019_gtFine_labelIds.png to test_01487_lbl.png
# transfer name from berlin_000455_000019_leftImg8bit.png to test_01487_ori.png
# transfer name from berlin_000132_000019_gtFine_labelIds.png to test_01488_lbl.png
# transfer name from berlin_000132_000019_leftImg8bit.png to test_01488_ori.png
# transfer name from berlin_000270_000019_gtFine_labelIds.png to test_01489_lbl.png
# transfer name from berlin_000270_000019_leftImg8bit.png to test_01489_ori.png
# transfer name from berlin_000520_000019_gtFine_labelIds.png to test_01490_lbl.png
# transfer name from berlin_000520_000019_leftImg8bit.png to test_01490_ori.png
# transfer name from berlin_000047_000019_gtFine_labelIds.png to test_01491_lbl.png
# transfer name from berlin_000047_000019_leftImg8bit.png to test_01491_ori.png
# transfer name from berlin_000429_000019_gtFine_labelIds.png to test_01492_lbl.png
# transfer name from berlin_000429_000019_leftImg8bit.png to test_01492_ori.png
# transfer name from berlin_000495_000019_gtFine_labelIds.png to test_01493_lbl.png
# transfer name from berlin_000495_000019_leftImg8bit.png to test_01493_ori.png
# transfer name from berlin_000379_000019_gtFine_labelIds.png to test_01494_lbl.png
# transfer name from berlin_000379_000019_leftImg8bit.png to test_01494_ori.png
# transfer name from berlin_000186_000019_gtFine_labelIds.png to test_01495_lbl.png
# transfer name from berlin_000186_000019_leftImg8bit.png to test_01495_ori.png
# transfer name from berlin_000204_000019_gtFine_labelIds.png to test_01496_lbl.png
# transfer name from berlin_000204_000019_leftImg8bit.png to test_01496_ori.png
# transfer name from berlin_000033_000019_gtFine_labelIds.png to test_01497_lbl.png
# transfer name from berlin_000033_000019_leftImg8bit.png to test_01497_ori.png
# transfer name from berlin_000409_000019_gtFine_labelIds.png to test_01498_lbl.png
# transfer name from berlin_000409_000019_leftImg8bit.png to test_01498_ori.png
# transfer name from berlin_000359_000019_gtFine_labelIds.png to test_01499_lbl.png
# transfer name from berlin_000359_000019_leftImg8bit.png to test_01499_ori.png
# transfer name from berlin_000250_000019_gtFine_labelIds.png to test_01500_lbl.png
# transfer name from berlin_000250_000019_leftImg8bit.png to test_01500_ori.png
# transfer name from berlin_000500_000019_gtFine_labelIds.png to test_01501_lbl.png
# transfer name from berlin_000500_000019_leftImg8bit.png to test_01501_ori.png
# transfer name from berlin_000067_000019_gtFine_labelIds.png to test_01502_lbl.png
# transfer name from berlin_000067_000019_leftImg8bit.png to test_01502_ori.png
# transfer name from berlin_000224_000019_gtFine_labelIds.png to test_01503_lbl.png
# transfer name from berlin_000224_000019_leftImg8bit.png to test_01503_ori.png
# transfer name from berlin_000298_000019_gtFine_labelIds.png to test_01504_lbl.png
# transfer name from berlin_000298_000019_leftImg8bit.png to test_01504_ori.png
# transfer name from berlin_000013_000019_gtFine_labelIds.png to test_01505_lbl.png
# transfer name from berlin_000013_000019_leftImg8bit.png to test_01505_ori.png
# transfer name from berlin_000391_000019_gtFine_labelIds.png to test_01506_lbl.png
# transfer name from berlin_000391_000019_leftImg8bit.png to test_01506_ori.png
# transfer name from berlin_000244_000019_gtFine_labelIds.png to test_01507_lbl.png
# transfer name from berlin_000244_000019_leftImg8bit.png to test_01507_ori.png
# transfer name from berlin_000514_000019_gtFine_labelIds.png to test_01508_lbl.png
# transfer name from berlin_000514_000019_leftImg8bit.png to test_01508_ori.png
# transfer name from berlin_000073_000019_gtFine_labelIds.png to test_01509_lbl.png
# transfer name from berlin_000073_000019_leftImg8bit.png to test_01509_ori.png
# transfer name from berlin_000230_000019_gtFine_labelIds.png to test_01510_lbl.png
# transfer name from berlin_000230_000019_leftImg8bit.png to test_01510_ori.png
# transfer name from berlin_000007_000019_gtFine_labelIds.png to test_01511_lbl.png
# transfer name from berlin_000007_000019_leftImg8bit.png to test_01511_ori.png
# transfer name from berlin_000469_000019_gtFine_labelIds.png to test_01512_lbl.png
# transfer name from berlin_000469_000019_leftImg8bit.png to test_01512_ori.png
# transfer name from berlin_000339_000019_gtFine_labelIds.png to test_01513_lbl.png
# transfer name from berlin_000339_000019_leftImg8bit.png to test_01513_ori.png
# transfer name from berlin_000385_000019_gtFine_labelIds.png to test_01514_lbl.png
# transfer name from berlin_000385_000019_leftImg8bit.png to test_01514_ori.png
# transfer name from berlin_000264_000019_gtFine_labelIds.png to test_01515_lbl.png
# transfer name from berlin_000264_000019_leftImg8bit.png to test_01515_ori.png
# transfer name from berlin_000534_000019_gtFine_labelIds.png to test_01516_lbl.png
# transfer name from berlin_000534_000019_leftImg8bit.png to test_01516_ori.png
# transfer name from berlin_000053_000019_gtFine_labelIds.png to test_01517_lbl.png
# transfer name from berlin_000053_000019_leftImg8bit.png to test_01517_ori.png
# transfer name from berlin_000481_000019_gtFine_labelIds.png to test_01518_lbl.png
# transfer name from berlin_000481_000019_leftImg8bit.png to test_01518_ori.png
# transfer name from berlin_000449_000019_gtFine_labelIds.png to test_01519_lbl.png
# transfer name from berlin_000449_000019_leftImg8bit.png to test_01519_ori.png
# transfer name from berlin_000319_000019_gtFine_labelIds.png to test_01520_lbl.png
# transfer name from berlin_000319_000019_leftImg8bit.png to test_01520_ori.png
# transfer name from berlin_000192_000019_gtFine_labelIds.png to test_01521_lbl.png
# transfer name from berlin_000192_000019_leftImg8bit.png to test_01521_ori.png
# transfer name from berlin_000210_000019_gtFine_labelIds.png to test_01522_lbl.png
# transfer name from berlin_000210_000019_leftImg8bit.png to test_01522_ori.png
# transfer name from berlin_000540_000019_gtFine_labelIds.png to test_01523_lbl.png
# transfer name from berlin_000540_000019_leftImg8bit.png to test_01523_ori.png
# transfer name from berlin_000027_000019_gtFine_labelIds.png to test_01524_lbl.png
# transfer name from berlin_000027_000019_leftImg8bit.png to test_01524_ori.png
